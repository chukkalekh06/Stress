# %%
from keras.models import Sequential
from keras.layers import Dense, Dropout
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score
import pickle

dataset = pd.read_csv('Latest-stress-dataset.csv')

dataset.head()

dataset.describe()

dataset.shape

dataset.columns

dataset.duplicated()

dataset.duplicated().sum()

dataset = dataset.drop_duplicates()

print(dataset.shape)

dataset.isna().sum()

sns.boxplot(data = dataset, x='Quality of sleeping Hours')

sns.boxplot(data = dataset, x='Times of Headache in each week')

sns.boxplot(data = dataset, x='Academic Performance')

sns.boxplot(data = dataset, x='Hours of study in each day')

sns.boxplot(data = dataset, x='Hours of extracurricular activities in each day')

dataset

corr = dataset.corr()
corr

sns.heatmap(corr,annot=True,cbar=True, cmap='coolwarm')

dataset.info()

len(dataset['Stress'].value_counts())

dataset['Stress'].value_counts()

sns.countplot(x='Stress',data=dataset)
plt.xticks(fontsize=5)
plt.show()

plt.figure(figsize=(10,10))
sns.heatmap(dataset.corr())

dataset.info()

features_to_encode = ['Quality of sleeping Hours', 'Times of Headache in each week', 'Academic Performance', 'Hours of study in each day', 'Hours of extracurricular activities in each day']
target_columns = ['Stress']

from sklearn.preprocessing import LabelEncoder
label_encoders = {}

for target_column in target_columns:
    if dataset[target_column].dtype == 'object':
        le_target = LabelEncoder()
        dataset[target_column] = le_target.fit_transform(dataset[target_column])
        label_encoders[target_column] = le_target

X = dataset[features_to_encode]
Y = dataset[target_columns]

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.3, random_state=7)

scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)
